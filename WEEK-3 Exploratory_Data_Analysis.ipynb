# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# Exploratory Data Analysis (EDA) is an approach to analyze the data using visual techniques. It is used to discover trends, patterns, or to check assumptions with the help of statistical summary and graphical representations.

# %% [raw]
# 1.Identify the null values in  the iris data set.
# 2.Identify null values in each column.
# 3.Identify the redundant(repeated) rows in the dataset.
# 4.Fill the null values with the mean,median.
# 5.Normalize the data using standard scaler and Min-Max Scaler.
# 6.Implement a heatmap and identify the correlation among the features.
# 7.Design a pair-plot and analyse the correlation among the features.
# 8.Rename the columns names  and converting the type of colums to another.

# %% [markdown]
# ##### IMPORTING THE LIBRARIES

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd

# %% [markdown]
# ##### Import iris data set

# %%
data_set= pd.read_csv(r'C:\Users\Admin\20071A05A2_ML_LAB\DataSets\Iris.csv')

# %% [markdown]
# Checking the dataset

# %%
data_set.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data_set.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %% [markdown]
# Checking the number of null values of each columns

# %%
data_set.head(100).isnull().sum()
# Out:
# Id               0
# SepalLengthCm    3
# SepalWidthCm     3
# PetalLengthCm    3
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# Checking total number of null values

# %%
data_set.head(100).isnull().sum().sum()
# Out:
# 9

# %% [markdown]
# Filling NULL values with 0 for a Column

# %%
data_set['SepalLengthCm']=data_set['SepalLengthCm'].fillna(0)

# %% [markdown]
# Checking if still NULL are left in SepalLengthCm column

# %%
data_set['SepalLengthCm'].head(100).isnull().sum()
# Out:
# 0

# %% [markdown]
# Checking NULL values in SepalWidthCm column

# %%
data_set['SepalWidthCm'].head(100).isnull().sum()
# Out:
# 3

# %% [markdown]
# Replacing the NULL values in SepalWidthCm column with mean

# %%
data_set['SepalWidthCm']=data_set['SepalWidthCm'].fillna(data_set['SepalWidthCm'].mean())

# %% [markdown]
# Checking if NULL values are replaced or not

# %%
data_set['SepalWidthCm'].head(100).isnull().sum()
# Out:
# 0

# %% [markdown]
# Checking NULL values in PetalLength column

# %%
data_set['PetalLengthCm'].head(100).isnull().sum()
# Out:
# 3

# %% [markdown]
# Replacing NULLvalues in PetalLengthCm with Median value

# %%
data_set['PetalLengthCm']=data_set['PetalLengthCm'].fillna(data_set['PetalLengthCm'].median())

# %% [markdown]
# Checking if NULL values are replaced or not

# %%
data_set['PetalLengthCm'].head(100).isnull().sum()
# Out:
# 0

# %% [markdown]
# CHECKING IF NULL VALUES ARE REPLACED IN THE ENTIRE DATASET

# %%
data_set.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
print("The Total NULL values are :" ,data_set.isnull().sum().sum())
# Out:
# The Total NULL values are : 0

# %% [markdown]
# WORKING ON BLACK FRIDAY SALES DATASET

# %%
bf_dataset= pd.read_csv(r'C:\Users\Admin\20071A05A2_ML_LAB\DataSets\BlackFridaySalesPrediction.csv')

# %%
bf_dataset.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
bf_dataset.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %% [markdown]
# Total Records in dataset

# %%
print(len(bf_dataset))
# Out:
# 550068

# %% [markdown]
# Handling NULL values in bf_dataset

# %%
bf_dataset['Product_Category_2']=bf_dataset['Product_Category_2'].fillna(bf_dataset['Product_Category_2'].mean())

# %%
bf_dataset['Product_Category_2'].isnull().sum()
# Out:
# 0

# %%
bf_dataset['Product_Category_3']=bf_dataset['Product_Category_3'].fillna(bf_dataset['Product_Category_3'].mean())

# %%
bf_dataset['Product_Category_3'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Checking if all NULL values are replaced

# %%
bf_dataset.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
print("Total NULL values : ",bf_dataset.isnull().sum().sum())
# Out:
# Total NULL values :  0

# %% [markdown]
# HANDLING DUPLICATE ROWS IN THE DATASET

# %%
print("Duplicated rows" , bf_dataset.duplicated().sum())
# Out:
# Duplicated rows 0

# %% [markdown]
# Exporting BF data set to BlackFridaySalesPredictionModified.csv

# %%
bf_dataset.to_csv(r'C:\Users\Admin\20071A05A2_ML_LAB\DataSets\BlackFridaySalesPredictionModified.csv')

# %% [markdown]
# Dealing With MALL_CUSTOMERS_DATA

# %%
mall_dataset= pd.read_csv(r'C:\Users\Admin\20071A05A2_ML_LAB\DataSets\Mall_Customers.csv')

# %%
mall_dataset.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 198    False
# 199    False
# 200    False
# 201    False
# 202    False
# Length: 203, dtype: bool

# %% [markdown]
# Checking the number of duplicated rows

# %%
print("The number of duplicated rows are: ", mall_dataset.duplicated().sum())
# Out:
# The number of duplicated rows are:  3

# %%
mall_dataset.drop_duplicates().duplicated().sum()

#mall_dataset.drop_duplicates(mall_dataset['CustomerID'])
#we can use above for checking duplicates in specific columns only
# Out:
# 0

# %% [markdown]
# Modyfying the dataset by removing the duplicates

# %%
mall_dataset=mall_dataset.drop_duplicates()

# %% [markdown]
# Checking for duplicates after dropping duplicates

# %%
print("The duplicated rows are : ",mall_dataset.duplicated().sum())
# Out:
# The duplicated rows are :  0

# %% [markdown]
# EXPORTING MALL_DATASET TO CSV FILE AS MallCustomers_Modified.csv

# %%
bf_dataset.to_csv(r'C:\Users\Admin\20071A05A2_ML_LAB\DataSets\MallCustomers_Modified.csv')

# %% [markdown]
# # sklearn library

# %% [markdown]
# importing sklearn library

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
plt.plot(mall_dataset['Annual Income (k$)'],mall_dataset['Spending Score (1-100)'])

# %% [markdown]
# Using MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
mall_dataset[['Annual Income (k$)','Spending Score (1-100)']]=scaler.fit_transform(mall_dataset[['Annual Income (k$)','Spending Score (1-100)']])

# %%
plt.plot(mall_dataset['Annual Income (k$)'],mall_dataset['Spending Score (1-100)'])

# %% [markdown]
# Using Standard  Scaler

# %%
scaler = StandardScaler()

# %%
mall_dataset[['Annual Income (k$)','Spending Score (1-100)']]=scaler.fit_transform(mall_dataset[['Annual Income (k$)','Spending Score (1-100)']])

# %%
plt.plot(mall_dataset['Annual Income (k$)'],mall_dataset['Spending Score (1-100)'])

# %% [markdown]
# # Seaborn library

# %%
import seaborn as sns

# %% [markdown]
# Implementing heatmap

# %%
plt.figure(figsize=(8,7) )
cor_data_set=data_set[['SepalLengthCm', 'SepalWidthCm','PetalLengthCm','PetalWidthCm']].corr()
sns.heatmap(cor_data_set, annot=True, fmt="f")
# Out:
# <AxesSubplot:>

# %%
cor_data_set.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count       4.000000      4.000000       4.000000      4.000000
# mean        0.639690      0.022735       0.605589      0.606801
# std         0.523871      0.662371       0.683485      0.645456
# min        -0.137970     -0.416740      -0.416740     -0.354352
# 25%         0.580203     -0.369949       0.553666      0.526108
# 50%         0.848365     -0.246161       0.919548      0.890778
# 75%         0.907851      0.146523       0.971471      0.971471
# max         1.000000      1.000000       1.000000      1.000000

# %% [markdown]
# Implementing PairPlot for Iris Dataset

# %%
#data_set contains iris dataset
#data_set.drop('Id',axis=1,inplace=True)
#plt.figure(figsize=(3,2) )
sns.pairplot(data_set,hue="Species", palette="husl")

# %% [markdown]
# Changing Column Names for Mall Customer Data Set

# %%
mall_dataset.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19           -1.738999               -0.434801
# 1           2    Male   21           -1.738999                1.195704
# 2           3  Female   20           -1.700830               -1.715913
# 3           4  Female   23           -1.700830                1.040418
# 4           5  Female   31           -1.662660               -0.395980

# %% [markdown]
# Changing Annual Income(k$) to Yearly Income

# %%
mall_dataset.rename(columns = {'Annual Income (k$)':'Yearly Income'}, inplace = True)

# %%
mall_dataset.head()
# Out:
#    CustomerID  Gender  Age  Yearly Income  Spending Score (1-100)
# 0           1    Male   19      -1.738999               -0.434801
# 1           2    Male   21      -1.738999                1.195704
# 2           3  Female   20      -1.700830               -1.715913
# 3           4  Female   23      -1.700830                1.040418
# 4           5  Female   31      -1.662660               -0.395980

# %% [markdown]
# Changing DataTypes of Columns

# %%
mall_dataset.dtypes
# Out:
# CustomerID                  int64
# Gender                     object
# Age                         int64
# Yearly Income             float64
# Spending Score (1-100)    float64
# dtype: object

# %% [markdown]
# There are 3 methods to change the datatypes of columns
# 1.astype()
# 2.to_numeric()
# 3.convert_dtypes()

# %%
mall_dataset['Yearly Income']=mall_dataset['Yearly Income'].astype(int)

# %% [markdown]
# Change the income type to integer

# %%
mall_dataset.dtypes
# Out:
# CustomerID                  int64
# Gender                     object
# Age                         int64
# Yearly Income               int32
# Spending Score (1-100)    float64
# dtype: object
